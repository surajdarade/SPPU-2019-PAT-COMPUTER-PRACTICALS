# %%
print("""Data Wrangling II 
Create an “Academic performance” dataset of students and perform the following operations using 
Python. 
 
1. Scan all variables for missing values and inconsistencies. If there are missing values and/or 
inconsistencies, use any of the suitable techniques to deal with them.   
2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable 
techniques to deal with them.  
3. Apply data transformations on at least one of the variables. The purpose of this 
transformation should be one of the following reasons: to change the scale for better 
understanding of the variable, to convert a non-linear relation into a linear one, or to 
decrease the skewness and convert the distribution into a normal distribution.  
 
Reason and document your approach properly. """)
# Out:
# Data Wrangling II
# Create an “Academic performance” dataset of students and perform the following operations using
# Python.
#
# 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them.
# 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable
# techniques to deal with them.
# 3. Apply data transformations on at least one of the variables. The purpose of this
# transformation should be one of the following reasons: to change the scale for better
# understanding of the variable, to convert a non-linear relation into a linear one, or to
# decrease the skewness and convert the distribution into a normal distribution.
#
# Reason and document your approach properly.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
    'Student ID': range(1, 21),
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female',
               'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Age': [50, 17, 19, np.nan, 17, 18, np.nan, 17, 19, 18, np.nan, 62, 17, 18, 48, 17, np.nan, 18, 19, 17],
    'Class': [12, 1, 13, 12, 11, 12, 13, 2, 12, 13, 11, 12, 13, 11, 20, 13, 11, 12, 13, 11],
    'Math Score': [200, 90, 78, np.nan, 80, 108, 75, np.nan, 92, 86, 90, 85, np.nan, 192, 82, 90, 78, 85, 92, 88],
    'Science Score': [78, np.nan, 75, 82, 85, np.nan, 80, 88, 92, 78, np.nan, 90, 75, 85, np.nan, 80, 78, 92, 88, 82],
    'English Score': [92, 88, np.nan, 94, 85, 90, np.nan, 88, 92, 85, 80, 94, 85, 88, 92, 90, 92, 85, np.nan, 88],
    'Attendance': [90, np.nan, 85, 92, 88, np.nan, 90, 92, 85, 88, 92, 90, 85, np.nan, 90, 88, 92, 85, 90, np.nan],
    'Study Hours': [20, 15, np.nan, 22, 16, 18, np.nan, 20, 15, 18, 22, 16, 18, 20, 15, 18, 22, 16, 18, np.nan],
    'Extra-curricular': ['Football', 'Drama Club', 'Chess Club', 'Basketball', 'Music Band', 'Football', 'Drama Club',
                         'Chess Club', 'Basketball', 'Music Band', 'Football', 'Drama Club', 'Chess Club', 'Basketball',
                         'Music Band', 'Football', 'Drama Club', 'Chess Club', 'Basketball', 'Music Band'],
    'Overall Performance': [3.5, 3.8, 3.2, np.nan, 3.6, 3.9, 3.4, np.nan, 4.0, 3.7, 3.9, 3.5, np.nan, 3.8, 3.3, 3.7,
                            3.9, 3.6, 3.8, np.nan]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('academic_performance_dataset.csv', index=False)

# %%
df
# Out:
#     Student ID  Gender   Age  Class  Math Score  Science Score  English Score  \
# 0            1    Male  18.0     12        85.0           78.0           92.0
# 1            2  Female  17.0     11        90.0            NaN           88.0
# 2            3    Male  19.0     13        78.0           75.0            NaN
# 3            4  Female   NaN     12         NaN           82.0           94.0
# 4            5    Male  17.0     11        80.0           85.0           85.0
# 5            6  Female  18.0     12        88.0            NaN           90.0
# 6            7    Male   NaN     13        75.0           80.0            NaN
# 7            8  Female  17.0     11         NaN           88.0           88.0
# 8            9    Male  19.0     12        92.0           92.0           92.0
# 9           10  Female  18.0     13        86.0           78.0           85.0
# 10          11    Male   NaN     11        90.0            NaN           80.0
# ...

# %%
df.isnull().sum()
# Out:
# Student ID             0
# Gender                 0
# Age                    4
# Class                  0
# Math Score             3
# Science Score          4
# English Score          3
# Attendance             4
# Study Hours            3
# Extra-curricular       0
# Overall Performance    4
# dtype: int64

# %%
df['Math Score'] = df['Math Score'].fillna(df['Math Score'].mean())

# %%
df
# Out:
#     Student ID  Gender   Age  Class  Math Score  Science Score  English Score  \
# 0            1    Male  50.0     12  200.000000           78.0           92.0
# 1            2  Female  17.0      1   90.000000            NaN           88.0
# 2            3    Male  19.0     13   78.000000           75.0            NaN
# 3            4  Female   NaN     12   99.470588           82.0           94.0
# 4            5    Male  17.0     11   80.000000           85.0           85.0
# 5            6  Female  18.0     12  108.000000            NaN           90.0
# 6            7    Male   NaN     13   75.000000           80.0            NaN
# 7            8  Female  17.0      2   99.470588           88.0           88.0
# 8            9    Male  19.0     12   92.000000           92.0           92.0
# 9           10  Female  18.0     13   86.000000           78.0           85.0
# 10          11    Male   NaN     11   90.000000            NaN           80.0
# ...

# %%
df['Math Score'] = df['Math Score'].astype(int)

# %%
df
# Out:
#     Student ID  Gender   Age  Class  Math Score  Science Score  English Score  \
# 0            1    Male  50.0     12         200           78.0           92.0
# 1            2  Female  17.0      1          90            NaN           88.0
# 2            3    Male  19.0     13          78           75.0            NaN
# 3            4  Female   NaN     12          99           82.0           94.0
# 4            5    Male  17.0     11          80           85.0           85.0
# 5            6  Female  18.0     12         108            NaN           90.0
# 6            7    Male   NaN     13          75           80.0            NaN
# 7            8  Female  17.0      2          99           88.0           88.0
# 8            9    Male  19.0     12          92           92.0           92.0
# 9           10  Female  18.0     13          86           78.0           85.0
# 10          11    Male   NaN     11          90            NaN           80.0
# ...

# %%
df.isnull().sum()
# Out:
# Student ID             0
# Gender                 0
# Age                    4
# Class                  0
# Math Score             0
# Science Score          4
# English Score          3
# Attendance             4
# Study Hours            3
# Extra-curricular       0
# Overall Performance    4
# dtype: int64

# %%
df.dropna()
# Out:
#     Student ID  Gender   Age  Class  Math Score  Science Score  English Score  \
# 0            1    Male  50.0     12         200           78.0           92.0
# 4            5    Male  17.0     11          80           85.0           85.0
# 8            9    Male  19.0     12          92           92.0           92.0
# 9           10  Female  18.0     13          86           78.0           85.0
# 11          12  Female  62.0     12          85           90.0           94.0
# 15          16  Female  17.0     13          90           80.0           90.0
# 17          18  Female  18.0     12          85           92.0           85.0
#
#     Attendance  Study Hours Extra-curricular  Overall Performance
# 0         90.0         20.0         Football                  3.5
# 4         88.0         16.0       Music Band                  3.6
# 8         85.0         15.0       Basketball                  4.0
# 9         88.0         18.0       Music Band                  3.7
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def RemoveOutlier(df,var):
    Q1 = df[var].quantile(0.25)
    Q3 = df[var].quantile(0.75)
    IQR = Q3 - Q1
    high, low = Q3+1.5*IQR, Q1-1.5*IQR
    print("Highest allowed in variable:", var, high)
    print("lowest allowed in variable:", var, low)
    count = df[(df[var] > high) | (df[var] < low)][var].count()
    print('Total outliers in:',var,':',count)
    df = df[((df[var] >= low) & (df[var] <= high))]
    return df
df_filtered = RemoveOutlier(df, "Age")

# Create boxplot after removing outliers
sns.boxplot(data=df_filtered, x="Age")
plt.show()
# Out:
# Highest allowed in variable: Age 22.0
# lowest allowed in variable: Age 14.0
# Total outliers in: Age : 3
